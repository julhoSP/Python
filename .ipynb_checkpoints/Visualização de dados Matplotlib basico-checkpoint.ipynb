# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x = np.linspace(1, 10 , 100)

# %%
plt.plot(x, np.sin(x))
plt.show()

# %%
#Salvando a figura
fig = plt.figure()
plt.plot(x, np.sin(x))

# %%
#salva a imagem
fig.savefig('sin.png')
